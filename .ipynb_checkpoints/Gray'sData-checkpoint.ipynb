# %% [markdown]
# https://data.wprdc.org/dataset/arrest-data

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-73e6add727ce> in <module>
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#       4 import matplotlib.pyplot as plt
# ----> 5 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
arrest_pandas = pd.read_csv("ArrestData.csv")

arrest_pandas.head()
# Out:
#         PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 0  1975272  16158872  42.0      F    B  2016-08-24T12:20:00
# 1  1974456  16144120  31.0      M    W  2016-08-03T14:55:00
# 2  1974466  16144165  63.0      F    B  2016-08-03T16:45:00
# 3  1974550  16145257  25.0      F    W  2016-08-05T02:36:00
# 4  1974596  16145962  25.0      M    B  2016-08-06T02:00:00
#
#                                      ARRESTLOCATION  \
# 0         4700 Block Centre AV Pittsburgh, PA 15213
# 1  4200 Block Steubenville PKE Pittsburgh, PA 15205
# 2        900 Block Freeport RD Fox Chapel, PA 15238
# 3       Foreland ST & Cedar AV Pittsburgh, PA 15212
# 4         900 Block Woodlow ST Pittsburgh, PA 15205
#
#                                             OFFENSES  \
# 0                                 3929 Retail Theft.
# 1       13(a)(16) Possession of Controlled Substance
# 2                                 3929 Retail Theft.
# 3  5503 Disorderly Conduct. / 5505 Public Drunken...
# 4  2702 Aggravated Assault. / 2705 Recklessy Enda...
#
#                                    INCIDENTLOCATION INCIDENTNEIGHBORHOOD  \
# 0         4700 Block Centre AV Pittsburgh, PA 15213           Bloomfield
# 1  4200 Block Steubenville PKE Pittsburgh, PA 15205         Outside City
# 2        900 Block Freeport RD Fox Chapel, PA 15238             Westwood
# 3       Foreland ST & Cedar AV Pittsburgh, PA 15212       East Allegheny
# 4         900 Block Woodlow ST Pittsburgh, PA 15205      Crafton Heights
#
#   INCIDENTZONE  INCIDENTTRACT  COUNCIL_DISTRICT  PUBLIC_WORKS_DIVISION  \
# 0            5          804.0               8.0                    2.0
# 1          OSC         5599.0               NaN                    NaN
# 2            5         2811.0               9.0                    2.0
# 3            1         2304.0               1.0                    1.0
# 4            5         2814.0               2.0                    5.0
#
#            X          Y
# 0 -79.949277  40.452551
# 1 -80.088018  40.440136
# 2 -79.891803  40.486625
# 3 -80.001939  40.454080
# 4 -80.052204  40.445900

# %%
df = pd.DataFrame(arrest_pandas)
df['ZipCodes'] = df['ARRESTLOCATION'].str.split().str[-1]

dfsorted = df.sort_values(by = ['ZipCodes'])
dfsorted.head(1000)
# Out:
#             PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 24648  2005806  18188634  18.0      F    W  2018-09-24T21:49:00
# 1481   1976306  16179695  26.0      F    B  2016-10-04T22:45:00
# 36113  2020459  19220662  56.0      M    W  2019-10-29T09:48:00
# 36109  2020455  19220436  37.0      M    W  2019-10-29T01:00:00
# 10117  1987270  17119676  28.0      F    B  2017-06-28T12:56:00
# ...        ...       ...   ...    ...  ...                  ...
# 9026   1986010  17099708  23.0      M    W  2017-05-31T18:40:00
# 8634   1985484  17091820  37.0      F    W  2017-05-20T00:39:00
# 40796  2027004  20092068  40.0      M    W  2020-05-18T11:45:00
# 42099  2028843  20127858  59.0      M    W  2020-07-11T22:53:00
# 9025   1986009  17099708  23.0      M    W  2017-05-31T18:40:00
#
#                                           ARRESTLOCATION  \
# 24648                                             Zone 1
# 1481                                              Zone 1
# 36113                                             Zone 1
# 36109                                             Zone 1
# 10117                                             Zone 1
# ...                                                  ...
# 9026   4400 Block Stanton AV & McCandless AV Pittsbur...
# 8634           5100 Block Butler ST Pittsburgh, PA 15201
# 40796             200 Block 57th ST Pittsburgh, PA 15201
# 42099       Woodbine ST & Arcade WY Pittsburgh, PA 15201
# 9025   4400 Block Stanton AV & McCandless AV Pittsbur...
#
#                                                 OFFENSES  \
# 24648  2701 Simple Assault. / 2718(a)(1) Strangulatio...
# 1481   2701 Simple Assault. / 2701(b)(2) Simple Assau...
# 36113  3304 Criminal Mischief. / 3127(a) Indecent exp...
# 36109  3304 Criminal Mischief. / 5505 Public Drunkenn...
# 10117  2706 Terroristic Threats. / 2904 Interference ...
# ...                                                  ...
# 9026   13(a)(16) Possession of Controlled Substance /...
# 8634   6308(a) Underage Purchase, Consume, Possessed ...
# 40796                    9093 Indirect Criminal Contempt
# 42099  3323 Stop Signs and Yield Signs. / 3731 Drivin...
# 9025         13(a)(32) Paraphernalia - Use or Possession
#
#                                         INCIDENTLOCATION INCIDENTNEIGHBORHOOD  \
# 24648                                             Zone 1                  NaN
# 1481                                              Zone 1                  NaN
# 36113                                             Zone 1                  NaN
# 36109                                             Zone 1                  NaN
# 10117                                             Zone 1                  NaN
# ...                                                  ...                  ...
# 9026   4400 Block Stanton AV & McCandless AV Pittsbur...      Stanton Heights
# 8634           5100 Block Butler ST Pittsburgh, PA 15201  Upper Lawrenceville
# 40796             200 Block 57th ST Pittsburgh, PA 15201      Stanton Heights
# 42099        1100 Block Downlook ST Pittsburgh, PA 15201      Stanton Heights
# 9025   4400 Block Stanton AV & McCandless AV Pittsbur...      Stanton Heights
#
#       INCIDENTZONE  INCIDENTTRACT  COUNCIL_DISTRICT  PUBLIC_WORKS_DIVISION  \
# 24648            1            NaN               NaN                    NaN
# 1481             1            NaN               NaN                    NaN
# 36113            1            NaN               NaN                    NaN
# 36109            1            NaN               NaN                    NaN
# 10117            1            NaN               NaN                    NaN
# ...            ...            ...               ...                    ...
# 9026             5         1018.0               NaN                    NaN
# 8634             2         1011.0               7.0                    2.0
# 40796            5         1018.0               7.0                    2.0
# 42099            5         1018.0               7.0                    2.0
# 9025             5         1018.0               NaN                    NaN
#
#                X          Y ZipCodes
# 24648        NaN        NaN        1
# 1481         NaN        NaN        1
# 36113        NaN        NaN        1
# 36109        NaN        NaN        1
# 10117        NaN        NaN        1
# ...          ...        ...      ...
# 9026    0.000000   0.000000    15201
# 8634  -79.955435  40.478364    15201
# 40796 -79.945777  40.484437    15201
# 42099 -79.939608  40.483728    15201
# 9025    0.000000   0.000000    15201
#
# [1000 rows x 17 columns]

# %%
zipcodeFrequency = df['ZipCodes']
zipcodeCounts = pd.Series(zipcodeFrequency).value_counts()
print(zipcodeCounts)
# Out:
# 15219    14814
# 15212     5708
# 15210     3223
# 15206     2786
# 15203     2149
#          ...
# 18801        1
# 19403        1
# 15084        1
# 15317        1
# 15642        1
# Name: ZipCodes, Length: 130, dtype: int64

# %%
zipcodeCounts.plot.barh(rot = 4)
# Out:
# <AxesSubplot:>
