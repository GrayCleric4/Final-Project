# %% [markdown]
# ## Dataset
# https://data.wprdc.org/dataset/allegheny-county-restaurant-food-facility-inspection-violations/resource/112a3821-334d-4f3f-ab40-4de1220b1a0a

# %%
import pandas as pd

restaurants_all = pd.read_csv("r.csv")

# %%
query_mask = restaurants_all['status'] > 1
zip_mask_low = restaurants_all['zip'] > 14999.0
zip_mask_high = restaurants_all['zip'] < 16000.0
open_restaurants = restaurants_all[query_mask]
open_restaurants = open_restaurants[zip_mask_low]
open_restaurants = open_restaurants[zip_mask_high]
open_restaurants = open_restaurants[open_restaurants['zip'].notnull()]
open_restaurants.head(5)
# Out:
# /opt/anaconda3/envs/cmpinf0010/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /opt/anaconda3/envs/cmpinf0010/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#       id         facility_name     num         street         city state  \
# 1  10781   Hill Top Lodge #151  128-30     Ormsby Ave   Pittsburgh    PA
# 2  10693     The Suburban Room    3113  W Liberty Ave   Pittsburgh    PA
# 3  10707         Hyd A Way Bar     NaN         Box 39       Morgan    PA
# 5  10730  Aleppo Firemens Club     NaN       Weber Rd    Sewickley    PA
# 7  10655                  Ames    5775     Baptist Rd  Bethel Park    PA
#
#        zip      municipal  category_cd                      description  ...  \
# 1  15210.0      Mt Oliver          250             Social Club-Bar Only  ...
# 2  15216.0        Dormont          201           Restaurant with Liquor  ...
# 3  15064.0  South Fayette          201           Restaurant with Liquor  ...
# 5  15143.0         Aleppo          250             Social Club-Bar Only  ...
# 7  15102.0    Bethel Park          212  Chain Restaurant without Liquor  ...
#
#    bus_st_date bus_cl_date seat_count noroom  sq_feet  status  placard_st  \
# 1   1984-06-17         NaN       35.0    NaN      NaN       7         NaN
# 2   1984-06-17         NaN       41.0    NaN      NaN       7         1.0
# 3   1987-03-01         NaN       30.0    NaN      NaN       7         NaN
# 5   1984-06-17         NaN       75.0    NaN      NaN       7         NaN
# 7   1999-04-15         NaN       13.0    NaN      NaN       7         NaN
#
#            x          y                                  address
# 1        NaN        NaN   128-30 Ormsby Ave Pittsburgh, PA 15210
# 2        NaN        NaN  3113 W Liberty Ave Pittsburgh, PA 15216
# 3        NaN        NaN                  Box 39 Morgan, PA 15064
# 5        NaN        NaN             Weber Rd Sewickley, PA 15143
# 7 -80.014728  40.348882    5775 Baptist Rd Bethel Park, PA 15102
#
# [5 rows x 22 columns]

# %%
zipcode_counter = dict()

for row in open_restaurants.index:
    zipc = open_restaurants.loc[row, "zip"]
    
    if zipc not in zipcode_counter:
        zipcode_counter[zipc] = 1
    else:
        zipcode_counter[zipc] = zipcode_counter[zipc] + 1

zipcode_counter
zip_sorted = dict(sorted(zipcode_counter.items(), key=lambda item: item[1]))
zip_sorted
# Out:
# {15047.0: 1,
#  15445.0: 1,
#  15259.0: 1,
#  15642.0: 1,
#  15244.0: 1,
#  15022.0: 1,
#  15312.0: 1,
#  15693.0: 1,
#  15038.0: 1,
#  15009.0: 1,
#  15367.0: 1,
#  15301.0: 1,
#  15644.0: 1,
#  15650.0: 1,
#  15085.0: 1,
#  15083.0: 1,
#  15061.0: 1,
#  15087.0: 1,
#  15089.0: 1,
#  15610.0: 1,
#  15230.0: 2,
#  15690.0: 2,
#  15601.0: 2,
#  15317.0: 3,
#  15321.0: 3,
#  15082.0: 3,
#  15006.0: 3,
#  15020.0: 3,
#  15242.0: 3,
#  15127.0: 4,
#  15332.0: 4,
#  15051.0: 4,
#  15001.0: 4,
#  15015.0: 5,
#  15240.0: 5,
#  15063.0: 6,
#  15018.0: 6,
#  15276.0: 6,
#  15057.0: 7,
#  15075.0: 7,
#  15032.0: 7,
#  15088.0: 8,
#  15046.0: 8,
#  15260.0: 9,
#  15068.0: 10,
#  15064.0: 11,
#  15003.0: 11,
#  15030.0: 11,
#  15026.0: 12,
#  15142.0: 14,
#  15031.0: 15,
#  15282.0: 15,
#  15035.0: 17,
#  15007.0: 18,
#  15056.0: 20,
#  15091.0: 24,
#  15225.0: 27,
#  15140.0: 30,
#  15086.0: 30,
#  15076.0: 32,
#  15148.0: 34,
#  15014.0: 39,
#  15243.0: 41,
#  15034.0: 42,
#  15133.0: 42,
#  15126.0: 44,
#  15112.0: 47,
#  15261.0: 48,
#  15135.0: 50,
#  15129.0: 55,
#  15144.0: 57,
#  15045.0: 60,
#  15116.0: 67,
#  15123.0: 70,
#  15211.0: 71,
#  15139.0: 72,
#  15204.0: 79,
#  15145.0: 80,
#  15024.0: 83,
#  15233.0: 85,
#  15071.0: 89,
#  15207.0: 93,
#  15214.0: 94,
#  15275.0: 97,
#  15131.0: 100,
#  15229.0: 105,
#  15037.0: 113,
#  15110.0: 114,
#  15223.0: 120,
#  15143.0: 124,
#  15065.0: 130,
#  15104.0: 138,
#  15228.0: 142,
#  15239.0: 146,
#  15044.0: 148,
#  15232.0: 152,
#  15209.0: 153,
#  15084.0: 160,
#  15241.0: 166,
#  15218.0: 167,
#  15101.0: 168,
#  15090.0: 175,
#  15226.0: 176,
#  15234.0: 177,
#  15208.0: 179,
#  15137.0: 180,
#  15231.0: 193,
#  15147.0: 195,
#  15202.0: 206,
#  15238.0: 206,
#  15215.0: 209,
#  15025.0: 217,
#  15220.0: 219,
#  15227.0: 221,
#  15102.0: 244,
#  15201.0: 262,
#  15017.0: 265,
#  15106.0: 265,
#  15236.0: 268,
#  15217.0: 275,
#  15216.0: 280,
#  15224.0: 294,
#  15122.0: 295,
#  15120.0: 318,
#  15221.0: 338,
#  15136.0: 342,
#  15132.0: 373,
#  15210.0: 375,
#  15206.0: 391,
#  15203.0: 392,
#  15235.0: 396,
#  15108.0: 408,
#  15205.0: 423,
#  15146.0: 482,
#  15237.0: 509,
#  15219.0: 639,
#  15213.0: 677,
#  15212.0: 694,
#  15222.0: 1041}

# %%
#all_values = zipcode_counter.values()
#max_value = max(all_values)

#print(max_value)

max_key = max(zipcode_counter, key=zipcode_counter.get)
print(max_key)

min_key = min(zipcode_counter, key=zipcode_counter.get)
print(min_key)
# Out:
# 15222.0
# 15047.0

# %%
print(len(zip_sorted))

zipcode_points_restaurants = dict()
i = 1

for key in zip_sorted:
    zipcode_points_restaurants[key] = i // 28 + 1
    i = i + 1
    
zipcode_points_restaurants
# Out:
# 139
# {15047.0: 1,
#  15445.0: 1,
#  15259.0: 1,
#  15642.0: 1,
#  15244.0: 1,
#  15022.0: 1,
#  15312.0: 1,
#  15693.0: 1,
#  15038.0: 1,
#  15009.0: 1,
#  15367.0: 1,
#  15301.0: 1,
#  15644.0: 1,
#  15650.0: 1,
#  15085.0: 1,
#  15083.0: 1,
#  15061.0: 1,
#  15087.0: 1,
#  15089.0: 1,
#  15610.0: 1,
#  15230.0: 1,
#  15690.0: 1,
#  15601.0: 1,
#  15317.0: 1,
#  15321.0: 1,
#  15082.0: 1,
#  15006.0: 1,
#  15020.0: 2,
#  15242.0: 2,
#  15127.0: 2,
#  15332.0: 2,
#  15051.0: 2,
#  15001.0: 2,
#  15015.0: 2,
#  15240.0: 2,
#  15063.0: 2,
#  15018.0: 2,
#  15276.0: 2,
#  15057.0: 2,
#  15075.0: 2,
#  15032.0: 2,
#  15088.0: 2,
#  15046.0: 2,
#  15260.0: 2,
#  15068.0: 2,
#  15064.0: 2,
#  15003.0: 2,
#  15030.0: 2,
#  15026.0: 2,
#  15142.0: 2,
#  15031.0: 2,
#  15282.0: 2,
#  15035.0: 2,
#  15007.0: 2,
#  15056.0: 2,
#  15091.0: 3,
#  15225.0: 3,
#  15140.0: 3,
#  15086.0: 3,
#  15076.0: 3,
#  15148.0: 3,
#  15014.0: 3,
#  15243.0: 3,
#  15034.0: 3,
#  15133.0: 3,
#  15126.0: 3,
#  15112.0: 3,
#  15261.0: 3,
#  15135.0: 3,
#  15129.0: 3,
#  15144.0: 3,
#  15045.0: 3,
#  15116.0: 3,
#  15123.0: 3,
#  15211.0: 3,
#  15139.0: 3,
#  15204.0: 3,
#  15145.0: 3,
#  15024.0: 3,
#  15233.0: 3,
#  15071.0: 3,
#  15207.0: 3,
#  15214.0: 3,
#  15275.0: 4,
#  15131.0: 4,
#  15229.0: 4,
#  15037.0: 4,
#  15110.0: 4,
#  15223.0: 4,
#  15143.0: 4,
#  15065.0: 4,
#  15104.0: 4,
#  15228.0: 4,
#  15239.0: 4,
#  15044.0: 4,
#  15232.0: 4,
#  15209.0: 4,
#  15084.0: 4,
#  15241.0: 4,
#  15218.0: 4,
#  15101.0: 4,
#  15090.0: 4,
#  15226.0: 4,
#  15234.0: 4,
#  15208.0: 4,
#  15137.0: 4,
#  15231.0: 4,
#  15147.0: 4,
#  15202.0: 4,
#  15238.0: 4,
#  15215.0: 4,
#  15025.0: 5,
#  15220.0: 5,
#  15227.0: 5,
#  15102.0: 5,
#  15201.0: 5,
#  15017.0: 5,
#  15106.0: 5,
#  15236.0: 5,
#  15217.0: 5,
#  15216.0: 5,
#  15224.0: 5,
#  15122.0: 5,
#  15120.0: 5,
#  15221.0: 5,
#  15136.0: 5,
#  15132.0: 5,
#  15210.0: 5,
#  15206.0: 5,
#  15203.0: 5,
#  15235.0: 5,
#  15108.0: 5,
#  15205.0: 5,
#  15146.0: 5,
#  15237.0: 5,
#  15219.0: 5,
#  15213.0: 5,
#  15212.0: 5,
#  15222.0: 5}
